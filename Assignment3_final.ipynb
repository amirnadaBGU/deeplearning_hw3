# %% [markdown]
# # Deep Learning and Its Applications to Signal and Image Processing and Analysis - Assignment 3

# %% [markdown]
# ## Introduction
# In this assignment, you will perform an image classification task on the CIFAR-10 dataset using two
# model families: Convolutional Neural Networks (CNNs) and Vision Transformers (ViTs). The objectives
# are to develop models, apply explainability tools (Grad-CAM and attention visualization), and evaluate
# comparative performance using confusion matrices and other metrics. In this assignment, you will also
# learn how to use the pytorch-lightning library. This library simplifies model building and training, and
# it also supports automatic logging to Weights & Biases. There is a complementary notebook attached
# to the assignment. A complementary notebook is provided with this assignment. It is intended for your
# convenience, and you are free to modify it as needed.

# %% [markdown]
# ### Imports and mount drive - in this notebook we will work on a pc. so do not need to use colab syntax
#
# # Deep Learning and Its Applications to Signal and
#
# ## Image Processing and Analysis
# ### 361.2.1120
# ### Home Work 2
#
# Alon Zeltser - 029644119
# Nadav Amir - 308339860

# %%
from typing import Any

import numpy as np
# skip this
# !pip install pytorch-lightning
# skip that
# 📦 Imports
import torch
import torch.nn as nn
import torch.nn.functional as F
import torchvision
import torchvision.transforms as transforms
from sympy import false
from torch.utils.data import random_split, DataLoader, Subset

import pytorch_lightning as pl
from torchsummary import summary
from twisted.mail.scripts.mailmail import success

import wandb

import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

# 🧹 Set seeds and configs
pl.seed_everything(42)
# Out:
# Seed set to 42
# 42

# %%
# skip this
# from google.colab import drive
# drive.mount('/content/drive')
# skip that

# %%
import os
# os.chdir('')

# %% [markdown]
# ## 1. CNN Classification and Grad-CAM Explainability

# %% [markdown]
# In this section, you will implement a CNN from scratch and apply Grad-CAM to explain the model predictions.

# %% [markdown]
# ###  1.1. Load and Preprocess CIFAR-10

# %% [markdown]
# a. load dataset:

# %%
# Define a transform to normalize the data
# Widely‑used baseline
cifar10_mean = (0.4914, 0.4822, 0.4465)
cifar10_std  = (0.2470, 0.2435, 0.2616)

# Source 1 for values: https://github.com/kuangliu/pytorch-cifar/issues/19
# Source 2 for values: https://stackoverflow.com/questions/69747119/pytorch-cifar10-images-are-not-normalized

transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize(cifar10_mean, cifar10_std),
])

#⬇️ Load dataset
dataset = torchvision.datasets.CIFAR10(root='./data', train=True, download=True, transform=transform)
test_dataset = torchvision.datasets.CIFAR10(root='./data', train=False, download=True, transform=transform)

# %% [markdown]
# a.plot sample images:

# %%
import random
import numpy as np
def get_class_name_from_idx(dictionary,idx):
    for key, value in dictionary.items():
        if value == idx:
            return key
def show_example_per_label(dataset):
    sample_targets = []
    sample_indices = []
    random.seed(423)
    for k,target in enumerate(dataset.targets):
        if random.random() < 0.05: # get different images every time
            if not target in sample_targets:
                sample_indices.append(k)
                sample_targets.append(target)
    sorted_indices_by_target = np.argsort(sample_targets)

    fig, axs = plt.subplots(nrows=2, ncols=5, figsize=(20, 10))

    row = 0
    index = 0
    switchbool= False
    for k in sorted_indices_by_target:
        axs[row,index]. grid(False)
        axs[row,index].set_title(f"Example of category: {sample_targets[k]} - {get_class_name_from_idx(dataset.class_to_idx,sample_targets[k])}")
        axs[row,index].imshow(dataset.data[sample_indices[k]])
        index+=1
        if index > 4 and switchbool== False:
            switchbool = True
            row = 1
            index = 0
    fig.tight_layout()
    plt.show()
show_example_per_label(dataset)

# %% [markdown]
# b. split - 30k train, 20k valid, 10k test (50,33.33,16.66)

# %%
from sklearn.model_selection import train_test_split
targets = dataset.targets

train_idx, valid_idx= train_test_split(
    np.arange(len(targets)), test_size=0.4, random_state=24, shuffle=True, stratify=targets)

train_dataset = Subset(dataset, train_idx)
validation_dataset = Subset(dataset, valid_idx)

print("Train dataset:" + str(len(train_dataset)))
print("Validation dataset:" + str(len(validation_dataset)))
print("Test dataset:" + str(len(test_dataset)))
# Out:
# Train dataset:30000
# Validation dataset:20000
# Test dataset:10000

# %% [markdown]
# c. preview categories histogram in each dataset

# %%
def plot_categories_histograms(set,header):
    # Extract class labels from the original dataset (Subset stores indices)
    # Supports subset or full dataset via try except mechanism on input
    try:
        labels = [set.dataset.targets[i] for i in set.indices]
    except:
        labels = [set.targets[i] for i in range(len(set.targets))]
    # Creating histogram dicts:
    counting_dict={}
    for k in range(10):
        counting_dict[k]=0
    # Count occurrences of each class
    for i,value in enumerate(np.array(labels)):
        counting_dict[value] +=1

    # Extract class indices and corresponding counts
    classes = list(counting_dict.keys())
    counts = [counting_dict[k] for k in classes]

    total = sum(counts)
    percentages = [count / total * 100 for count in counts]

    # Plotting training set histogram
    plt.figure(figsize=(8, 4))
    bars = plt.bar(classes, counts)
    plt.xlabel('Class')
    plt.ylabel('Count')
    plt.title(f'{header} Set Class Distribution')
    plt.xticks(classes)
    plt.tight_layout()

    # Add percentage labels on top of bars
    for bar, percent in zip(bars, percentages):
        height = bar.get_height()
        plt.text(bar.get_x() + bar.get_width() / 2, height , f'{percent:.1f}%',
                 ha='center', va='bottom', fontsize=10)

    plt.tight_layout()
    plt.show()

plot_categories_histograms(train_dataset, 'Training Set Categories')
plot_categories_histograms(validation_dataset, 'Validation Set Categories')
plot_categories_histograms(test_dataset, 'Test Set Categories')

# %% [markdown]
# ###  1.2. Define CNN in PyTorch Lightning

# %% [markdown]
# a.

# %%
import torchmetrics
import matplotlib.pyplot as plt, seaborn as sns, pandas as pd
from pytorch_lightning.loggers import WandbLogger
from pytorch_lightning.callbacks import ModelCheckpoint

class SimpleCNN(pl.LightningModule):
    def __init__(self, lr=0.001):
        super().__init__()
        self.save_hyperparameters()
        self.lr = lr
        self.loss = nn.CrossEntropyLoss()

        self.train_acc = torchmetrics.Accuracy(task="multiclass",
                                               num_classes=10)
        self.val_acc   = torchmetrics.Accuracy(task="multiclass",
                                               num_classes=10)
        self.test_acc  = torchmetrics.Accuracy(task="multiclass",
                                               num_classes=10)

        self.test_f1  = torchmetrics.F1Score(
            task='multiclass', num_classes=10,average=None)

        self.test_cm  = torchmetrics.ConfusionMatrix(
            task='multiclass', num_classes=10)

        def conv_bn_relu(c_in, c_out):
            return nn.Sequential(
                nn.Conv2d(c_in, c_out, 3, padding=1, bias=False),
                nn.BatchNorm2d(c_out),
                nn.ReLU(inplace=True)
            )

        # 3×32×32 → 256×8×8
        self.features = nn.Sequential(
            conv_bn_relu(3,   64),
            conv_bn_relu(64,  64),
            nn.MaxPool2d(2),          # 64×16×16

            conv_bn_relu(64, 128),
            conv_bn_relu(128,128),
            nn.MaxPool2d(2),          # 128×8×8

            conv_bn_relu(128,256),
            conv_bn_relu(256,256)
        )

        self.gap     = nn.AdaptiveAvgPool2d(1)      # 256×1×1
        self.dropout = nn.Dropout(0.3)
        self.fc      = nn.Linear(256, 10)

    def forward(self, x):
        x = self.features(x)
        x = self.gap(x).flatten(1)   # B×256
        x = self.dropout(x)
        return self.fc(x)

    def training_step(self, batch, batch_idx):
        loss, preds, y = self.common_step(batch, batch_idx)
        self.train_acc.update(preds,y)
        self.log("train_acc",self.train_acc,
                 on_step=False,on_epoch=True,prog_bar=True)
        self.log('train loss', loss, prog_bar=True)
        return loss

    def validation_step(self, batch, batch_idx):
        loss, preds, y = self.common_step(batch, batch_idx)
        self.val_acc.update(preds,y)
        self.log("val_acc",self.val_acc,
                 on_step=False,on_epoch=True,prog_bar=True)
        self.log('validation loss', loss, prog_bar=True)
        return loss


    def test_step(self, batch, batch_idx):
        loss, preds, y = self.common_step(batch, batch_idx)
        self.test_acc.update(preds,y)
        self.test_f1.update(preds, y)
        self.test_cm.update(preds, y)
        self.log("test_acc",self.test_acc,
                 on_step=False,on_epoch=True,prog_bar=True)
        self.log('test loss', loss, prog_bar=True)
        return loss

    def common_step(self, batch, batch_idx):
        x,y = batch
        scores = self.forward(x)
        loss = self.loss(scores, y)
        return loss, scores, y

    def predict_step(self,batch,batch_idx):
        x,y = batch
        scores = self.forward(x)
        preds = torch.argmax(scores, dim=1)
        return preds

    def on_test_epoch_end(self):
        def plot_f1_scores(f1):
            f1 = f1.detach().cpu().numpy()
            class_names = [str(i) for i in range(10)]
            fig, ax = plt.subplots(figsize=(8, 5))
            bars = ax.bar(class_names, f1, alpha=0.7, edgecolor='black')

            ax.set_xlabel("Class")
            ax.set_ylabel("F1 score")
            ax.set_title(f"Per class F1 (macro ≈ {f1.mean():.4f})")
            ax.set_ylim(0, 1.1)
            ax.grid(axis='y', linestyle='--', alpha=0.5)

            for bar, score in zip(bars, f1):
                ax.text(bar.get_x() + bar.get_width() / 2,
                        score + 0.02,
                        f"{score:.2f}",
                        ha='center', va='bottom', fontsize=10, fontweight='bold')

            fig.tight_layout()
            return fig

        def plot_conf_matrix(conf_mat):
            conf_mat = conf_mat.detach().cpu().numpy()
            row_sums = conf_mat.sum(axis=1, keepdims=True)
            conf_norm = np.divide(conf_mat, row_sums)
            n_classes = conf_norm.shape[0]
            class_names = [str(i) for i in range(n_classes)]
            df = pd.DataFrame(conf_norm, index=class_names, columns=class_names)

            fig, ax = plt.subplots(figsize=(8, 6))
            sns.heatmap(
                df,
                annot=True,
                fmt=".2f",
                cmap="Blues",
                vmin=0, vmax=1,
                cbar=True,
                ax=ax
            )
            ax.set_xlabel("Predicted label")
            ax.set_ylabel("True label")
            ax.set_title("Confusion matrix (row normalised)")
            fig.tight_layout()

            return fig

        f1_per_class =  self.test_f1.compute()
        fig1 = plot_f1_scores(f1_per_class)
        conf_mat = self.test_cm.compute()
        fig2 = plot_conf_matrix(conf_mat)


        self.logger.log_image("f1_scores",[fig1])
        self.logger.log_image("confusion_matrix",[fig2])

        self.test_f1.reset()
        self.test_cm.reset()

    def configure_optimizers(self):
        return torch.optim.Adam(self.parameters(), lr=self.lr)

# %%
from pytorch_lightning.callbacks import EarlyStopping

BATCH_SIZE = 256
train_loader = DataLoader(dataset=train_dataset, batch_size=BATCH_SIZE, shuffle=True)
validation_loader = DataLoader(dataset=validation_dataset, batch_size=BATCH_SIZE, shuffle=False)
test_loader = DataLoader(dataset=test_dataset, batch_size=BATCH_SIZE, shuffle=False)

# %% [markdown]
# b. Your model should achieve an accuracy of at least 0.80 on the training set, and at least 0.70 on both the validation and test sets.

# %%
# 🪄 Init wandb logger
wandb_logger = WandbLogger(project="CNN-CIFAR10", log_model=True)

# ⚡ Instantiate model and trainer
model = SimpleCNN()

# Define the checkpoint callback
early_stop = EarlyStopping(monitor="validation loss",mode="min", patience=10, verbose=True)
checkpoint_callback = ModelCheckpoint(save_top_k=1, monitor="validation loss", mode="min",verbose=True)

trainer = pl.Trainer(accelerator="gpu",devices=[0],min_epochs=5,max_epochs=30,callbacks=[early_stop,checkpoint_callback],logger=wandb_logger)

cnn_train = False
# Out:
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs

# %%
cnn_train = True
trainer.fit(model,train_loader,validation_loader)
# Out:
# You are using a CUDA device ('NVIDIA GeForce RTX 4060 Laptop GPU') that has Tensor Cores. To properly utilize them, you should set `torch.set_float32_matmul_precision('medium' | 'high')` which will trade-off precision for performance. For more details, read https://pytorch.org/docs/stable/generated/torch.set_float32_matmul_precision.html#torch.set_float32_matmul_precision
# wandb: ERROR Failed to detect the name of this notebook. You can set it manually with the WANDB_NOTEBOOK_NAME environment variable to enable code saving.
# wandb: Currently logged in as: ndvamr (ndvamr-ben-gurion-university-of-the-negev) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# creating run (0.2s)
# Tracking run with wandb version 0.19.11
# Run data is saved locally in <code>.\wandb\run-20250513_192620-7ta4v9qu</code>
# Syncing run <strong><a href='https://wandb.ai/ndvamr-ben-gurion-university-of-the-negev/CNN-CIFAR10/runs/7ta4v9qu' target="_blank">distinctive-plant-28</a></strong> to <a href='https://wandb.ai/ndvamr-ben-gurion-university-of-the-negev/CNN-CIFAR10' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/ndvamr-ben-gurion-university-of-the-negev/CNN-CIFAR10' target="_blank">https://wandb.ai/ndvamr-ben-gurion-university-of-the-negev/CNN-CIFAR10</a>
#  View run at <a href='https://wandb.ai/ndvamr-ben-gurion-university-of-the-negev/CNN-CIFAR10/runs/7ta4v9qu' target="_blank">https://wandb.ai/ndvamr-ben-gurion-university-of-the-negev/CNN-CIFAR10/runs/7ta4v9qu</a>
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#
#   | Name      | Type                      | Params | Mode
# ----------------------------------------------------------------
# 0 | loss      | CrossEntropyLoss          | 0      | train
# 1 | train_acc | MulticlassAccuracy        | 0      | train
# 2 | val_acc   | MulticlassAccuracy        | 0      | train
# 3 | test_acc  | MulticlassAccuracy        | 0      | train
# 4 | test_f1   | MulticlassF1Score         | 0      | train
# 5 | test_cm   | MulticlassConfusionMatrix | 0      | train
# 6 | features  | Sequential                | 1.1 M  | train
# 7 | gap       | AdaptiveAvgPool2d         | 0      | train
# 8 | dropout   | Dropout                   | 0      | train
# 9 | fc        | Linear                    | 2.6 K  | train
# ----------------------------------------------------------------
# 1.1 M     Trainable params
# 0         Non-trainable params
# 1.1 M     Total params
# 4.595     Total estimated model params size (MB)
# 36        Modules in train mode
# 0         Modules in eval mode
# Sanity Checking: |          | 0/? [00:00<?, ?it/s]
# C:\Users\ndvam\anaconda3\Lib\site-packages\pytorch_lightning\trainer\connectors\data_connector.py:425: The 'val_dataloader' does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` to `num_workers=15` in the `DataLoader` to improve performance.
# C:\Users\ndvam\anaconda3\Lib\site-packages\pytorch_lightning\trainer\connectors\data_connector.py:425: The 'train_dataloader' does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` to `num_workers=15` in the `DataLoader` to improve performance.
# Training: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Metric validation loss improved. New best score: 1.295
# Epoch 0, global step 118: 'validation loss' reached 1.29475 (best 1.29475), saving model to '.\\CNN-CIFAR10\\7ta4v9qu\\checkpoints\\epoch=0-step=118.ckpt' as top 1
# Validation: |          | 0/? [00:00<?, ?it/s]
# Metric validation loss improved by 0.143 >= min_delta = 0.0. New best score: 1.152
# Epoch 1, global step 236: 'validation loss' reached 1.15153 (best 1.15153), saving model to '.\\CNN-CIFAR10\\7ta4v9qu\\checkpoints\\epoch=1-step=236.ckpt' as top 1
# Validation: |          | 0/? [00:00<?, ?it/s]
# Epoch 2, global step 354: 'validation loss' was not in top 1
# Validation: |          | 0/? [00:00<?, ?it/s]
# Metric validation loss improved by 0.278 >= min_delta = 0.0. New best score: 0.874
# Epoch 3, global step 472: 'validation loss' reached 0.87373 (best 0.87373), saving model to '.\\CNN-CIFAR10\\7ta4v9qu\\checkpoints\\epoch=3-step=472.ckpt' as top 1
# Validation: |          | 0/? [00:00<?, ?it/s]
# Metric validation loss improved by 0.173 >= min_delta = 0.0. New best score: 0.700
# Epoch 4, global step 590: 'validation loss' reached 0.70047 (best 0.70047), saving model to '.\\CNN-CIFAR10\\7ta4v9qu\\checkpoints\\epoch=4-step=590.ckpt' as top 1
# Validation: |          | 0/? [00:00<?, ?it/s]
# Epoch 5, global step 708: 'validation loss' was not in top 1
# Validation: |          | 0/? [00:00<?, ?it/s]
# Epoch 6, global step 826: 'validation loss' was not in top 1
# Validation: |          | 0/? [00:00<?, ?it/s]
# Epoch 7, global step 944: 'validation loss' was not in top 1
# Validation: |          | 0/? [00:00<?, ?it/s]
# Epoch 8, global step 1062: 'validation loss' was not in top 1
# Validation: |          | 0/? [00:00<?, ?it/s]
# Metric validation loss improved by 0.011 >= min_delta = 0.0. New best score: 0.690
# Epoch 9, global step 1180: 'validation loss' reached 0.68957 (best 0.68957), saving model to '.\\CNN-CIFAR10\\7ta4v9qu\\checkpoints\\epoch=9-step=1180.ckpt' as top 1
# Validation: |          | 0/? [00:00<?, ?it/s]
# Epoch 10, global step 1298: 'validation loss' was not in top 1
# Validation: |          | 0/? [00:00<?, ?it/s]
# Epoch 11, global step 1416: 'validation loss' was not in top 1
# Validation: |          | 0/? [00:00<?, ?it/s]
# Epoch 12, global step 1534: 'validation loss' was not in top 1
# Validation: |          | 0/? [00:00<?, ?it/s]
# Epoch 13, global step 1652: 'validation loss' was not in top 1
# Validation: |          | 0/? [00:00<?, ?it/s]
# Epoch 14, global step 1770: 'validation loss' was not in top 1
# Validation: |          | 0/? [00:00<?, ?it/s]
# Epoch 15, global step 1888: 'validation loss' was not in top 1
# Validation: |          | 0/? [00:00<?, ?it/s]
# Epoch 16, global step 2006: 'validation loss' was not in top 1
# Validation: |          | 0/? [00:00<?, ?it/s]
# Epoch 17, global step 2124: 'validation loss' was not in top 1
# Validation: |          | 0/? [00:00<?, ?it/s]
# Epoch 18, global step 2242: 'validation loss' was not in top 1
# Validation: |          | 0/? [00:00<?, ?it/s]
# Monitored metric validation loss did not improve in the last 10 records. Best score: 0.690. Signaling Trainer to stop.
# Epoch 19, global step 2360: 'validation loss' was not in top 1

# %%
# Shows loss graph of best run
api = wandb.Api()
import wandb
import pandas as pd
import matplotlib.pyplot as plt
from scipy.ndimage import gaussian_filter1d

# Initialize W&B API
api = wandb.Api()

# Load your specific run
run = api.run("ndvamr-ben-gurion-university-of-the-negev/CNN-CIFAR10/7ta4v9qu")

train_dataset_size = 30000
steps_per_epoch = train_dataset_size // BATCH_SIZE



df_tl = run.history(keys=["train loss","epoch"])
df_tl = pd.DataFrame(df_tl)



df_vl = run.history(keys=["validation loss","epoch"])
df_vl = pd.DataFrame(df_vl)


# Apply Gaussian smoothing (sigma can be tuned)
train_loss_smoothed = gaussian_filter1d(df_tl["train loss"].fillna(method="ffill"), sigma=1)
val_loss_smoothed = gaussian_filter1d(df_vl["validation loss"].fillna(method="ffill"), sigma=1)

# Plot both
plt.figure(figsize=(10, 5))
plt.plot(df_tl["epoch"], train_loss_smoothed, label="Train Loss (smoothed)")
plt.plot(df_vl["epoch"], val_loss_smoothed, label="Validation Loss (smoothed)")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.title("Training & Validation Loss")
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# C:\Users\ndvam\AppData\Local\Temp\ipykernel_235108\2934033842.py:29: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   train_loss_smoothed = gaussian_filter1d(df_tl["train loss"].fillna(method="ffill"), sigma=1)
# C:\Users\ndvam\AppData\Local\Temp\ipykernel_235108\2934033842.py:30: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   val_loss_smoothed = gaussian_filter1d(df_vl["validation loss"].fillna(method="ffill"), sigma=1)

# %% [markdown]
# c.

# %%
# 🔍 Evaluate
if cnn_train:
    best_model = SimpleCNN.load_from_checkpoint(checkpoint_callback.best_model_path)
else:
    checkpoint_path = "C:/Users/ndvam/PycharmProjects/deeplearning_hw3/cnn_cifar10_best.ckpt"
    best_model = SimpleCNN.load_from_checkpoint(checkpoint_path)


trainer.validate(model=best_model,dataloaders=validation_loader)

trainer.test(model = best_model, dataloaders=test_loader)

#Show F1 score and confusion matrix you can do it in def on_test_epoch_end(self): and log it to wandb

# 💾 Save the model in thr last epoch if saved by metric
if cnn_train:
    trainer.save_checkpoint("cnn_cifar10_best.ckpt")
# Out:
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# C:\Users\ndvam\anaconda3\Lib\site-packages\pytorch_lightning\trainer\connectors\data_connector.py:425: The 'val_dataloader' does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` to `num_workers=15` in the `DataLoader` to improve performance.
# Validation: |          | 0/? [00:00<?, ?it/s]
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃      Validate metric      ┃       DataLoader 0        ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │          val_acc          │    0.7746000289916992     │
# │      validation loss      │    0.6895726323127747     │
# └───────────────────────────┴───────────────────────────┘
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# C:\Users\ndvam\anaconda3\Lib\site-packages\pytorch_lightning\trainer\connectors\data_connector.py:425: The 'test_dataloader' does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` to `num_workers=15` in the `DataLoader` to improve performance.
# Testing: |          | 0/? [00:00<?, ?it/s]
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃        Test metric        ┃       DataLoader 0        ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │         test loss         │    0.6868930459022522     │
# │         test_acc          │    0.7802000045776367     │
# └───────────────────────────┴───────────────────────────┘

# %% [markdown]
# ## 1.3 Explainability with Grad-CAM

# %% [markdown]
# a.

# %%
# !pip install grad-cam --quiet

# %%
from pytorch_grad_cam import GradCAM
from pytorch_grad_cam.utils.image import show_cam_on_image, preprocess_image
from pytorch_grad_cam.utils.model_targets import ClassifierOutputTarget

# load the model again
model = SimpleCNN.load_from_checkpoint("cnn_cifar10_best.ckpt")
model.eval()

# Define the target layer for Grad-CAM (adjust if needed)
target_layer = model.features[-1][0]

cam = GradCAM(model=model, target_layers=[target_layer])

# %% [markdown]
# First section of grad-cam - generate Grad-CAM heatmaps for several test images

# %%
from pytorch_grad_cam.utils.model_targets import ClassifierOutputTarget
import random
import numpy as np

cifar10_mean = (0.4914, 0.4822, 0.4465)
cifar10_std  = (0.2470, 0.2435, 0.2616)

def get_class_name_from_idx(dictionary,idx):
    for key, value in dictionary.items():
        if value == idx:
            return key
def show_example_per_label(dataset):
    sample_targets = []
    sample_indices = []
    random.seed(2228)
    for k,target in enumerate(dataset.targets):
        if random.random() < 0.05:
            if not target in sample_targets:
                sample_indices.append(k)
                sample_targets.append(target)
    sorted_indices_by_target = np.argsort(sample_targets)

    fig, axs = plt.subplots(nrows=2, ncols=5, figsize=(20, 10))

    index = 0
    for k in sorted_indices_by_target[[1, 5, 0, 2, 3]]:

        rgb_img = dataset.data[sample_indices[k]]/255.0
        category = sample_targets[k]
        axs[0,index]. grid(False)
        axs[0,index].set_title(f"Example of category - {get_class_name_from_idx(dataset.class_to_idx,sample_targets[k])}")
        axs[0,index].imshow(rgb_img)

        input_tensor = preprocess_image(rgb_img,mean=cifar10_mean,std=cifar10_std).float()

        # Show what model predicted
        with torch.no_grad():
            logits = model(input_tensor)
            probs = logits.softmax(dim=1).squeeze(0)
            pred_idx  = int(probs.argmax())

        grayscale_cam = cam(input_tensor=input_tensor, targets=[ClassifierOutputTarget(category)])
        grayscale_cam = grayscale_cam[0, :]
        visualization = show_cam_on_image(rgb_img, grayscale_cam, use_rgb=True)

        axs[1,index]. grid(False)
        axs[1,index].set_title(f"GradCam - True - {get_class_name_from_idx(dataset.class_to_idx,sample_targets[k])}, "
                               f"Prediction - {get_class_name_from_idx(dataset.class_to_idx,pred_idx)}")
        axs[1,index].imshow(visualization)
        index += 1
        if index == 5:
             break
    fig.tight_layout()
    plt.show()

show_example_per_label(test_dataset)

# %% [markdown]
# Second section of grad-cam - generate Grad-CAM heatmaps for several test images (looks for bad examples)

# %%
from pytorch_grad_cam.utils.model_targets import ClassifierOutputTarget
import random
import numpy as np

cifar10_mean = (0.4914, 0.4822, 0.4465)
cifar10_std  = (0.2470, 0.2435, 0.2616)

def get_class_name_from_idx(dictionary,idx):
    for key, value in dictionary.items():
        if value == idx:
            return key
def show_example_per_label(dataset):
    sample_targets = []
    sample_indices = []
    random.seed(442)
    for k,target in enumerate(dataset.targets):
        if random.random() < 0.1:
            rgb_img = dataset.data[k]/255.0
            input_tensor = preprocess_image(rgb_img,mean=cifar10_mean,std=cifar10_std).float()
            logits = model(input_tensor)
            probs = logits.softmax(dim=1).squeeze(0)
            pred_idx  = int(probs.argmax())
            if pred_idx != target:
                if not target in sample_targets:
                    sample_indices.append(k)
                    sample_targets.append(target)



    sorted_indices_by_target = np.argsort(sample_targets)

    fig, axs = plt.subplots(nrows=2, ncols=5, figsize=(20, 10))

    index = 0
    for k in sorted_indices_by_target[[1, 5, 0, 2, 3]]:

        rgb_img = dataset.data[sample_indices[k]]/255.0
        category = sample_targets[k]
        axs[0,index]. grid(False)
        axs[0,index].set_title(f"Example of category - {get_class_name_from_idx(dataset.class_to_idx,sample_targets[k])}")
        axs[0,index].imshow(rgb_img)

        input_tensor = preprocess_image(rgb_img,mean=cifar10_mean,std=cifar10_std).float()

        # Show what model predicted
        with torch.no_grad():
            logits = model(input_tensor)
            probs = logits.softmax(dim=1).squeeze(0)
            pred_idx  = int(probs.argmax())

        grayscale_cam = cam(input_tensor=input_tensor, targets=[ClassifierOutputTarget(category)])
        grayscale_cam = grayscale_cam[0, :]
        visualization = show_cam_on_image(rgb_img, grayscale_cam, use_rgb=True)

        axs[1,index]. grid(False)
        axs[1,index].set_title(f"GradCam - True - {get_class_name_from_idx(dataset.class_to_idx,sample_targets[k])}, "
                               f"Prediction - {get_class_name_from_idx(dataset.class_to_idx,pred_idx)}")
        axs[1,index].imshow(visualization)
        index += 1
        if index == 5:
             break
    fig.tight_layout()
    plt.show()

show_example_per_label(test_dataset)

# %% [markdown]
# ## 2. Vision Transformer (ViT) and Attention Visualization

# %% [markdown]
# In this section, you will implement a Vision Transformer (ViT) from scratch and compare it to the CNN
# model developed in Section 1. Additionally, you will visualize attention maps to gain insight into the
# model’s decision process.

# %% [markdown]
# ### 2.1 Implementing the Vision Transformer

# %% [markdown]
# a.

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torchvision
import torchvision.transforms as transforms
from torch.utils.data import random_split, DataLoader, Subset

import pytorch_lightning as pl

"""
Main source of information - building-a-vision-transformer-model-from-scratch by Matt Nguyen
https://medium.com/correll-lab/building-a-vision-transformer-model-from-scratch-a3054f707cc6
We followed the instructions in this tutorial alongside with several more tutorials on youtube and on medium.com
3blue1brown series about transformers - https://www.youtube.com/watch?v=wjZofJX0v4M
Alexander Otchensashenko turotrial on patch embedding - https://www.youtube.com/watch?v=ZysZnxKZ48I
Shusen Wang - Vision Transformer for image Classification - https://www.youtube.com/watch?v=HZ4j_U3FC94
Yanik Kilcher - An image is Worth 16x16 words - paper explanations - https://www.youtube.com/watch?v=TrdevFK_am4
Nikolaus Correll - Understanding Image Patch Embeddings https://medium.com/p/3d66c14fe7ed
"""

class PatchEmbedding(nn.Module):
  def __init__(self, d_model, img_size, patch_size, n_channels):
    super().__init__()

    self.d_model = d_model # Dimensionality of Model - 768
    self.img_size = img_size # Image Size - 32
    self.patch_size = patch_size # Patch Size - 8
    self.n_channels = n_channels # Number of Channels - 3

    self.linear_project = nn.Conv2d(self.n_channels, self.d_model, kernel_size=self.patch_size, stride=self.patch_size)

  # B: Batch Size - 128
  # C: Image Channels - 3
  # H: Image Height - 32
  # W: Image Width - 32
  # P_col: Patch Column - 8
  # P_row: Patch Row - 8
  def forward(self, x):
    x = self.linear_project(x) # (B, C, H, W) -> (B, d_model, P_col, P_row)

    x = x.flatten(2) # (B, d_model, P_col, P_row) -> (B, d_model, P)

    x = x.transpose(1, 2) # (B, d_model, P) -> (B, P, d_model)

    return x

class PositionalEncoding(nn.Module):
  def __init__(self, d_model, max_seq_length):
    super().__init__()

    self.cls_token = nn.Parameter(torch.randn(1, 1, d_model)) # Classification Token

    # Creating positional encoding
    pe = torch.zeros(max_seq_length, d_model) # max_seq_length = n_patches + 1

    for pos in range(max_seq_length):
      for i in range(d_model):
        if i % 2 == 0:
          pe[pos][i] = np.sin(pos/(10000 ** (i/d_model)))
        else:
          pe[pos][i] = np.cos(pos/(10000 ** ((i-1)/d_model)))

    self.register_buffer('pe', pe.unsqueeze(0))

  def forward(self, x):
    # Expand to have class token for every image in batch
    tokens_batch = self.cls_token.expand(x.size()[0], -1, -1)

    # Adding class tokens to the beginning of each embedding
    x = torch.cat((tokens_batch,x), dim=1)

    # Add positional encoding to embeddings
    x = x + self.pe

    return x

class AttentionHead(nn.Module):
  def __init__(self, d_model, head_size):
    super().__init__()
    self.head_size = head_size # d_model / n_heads 48

    self.query = nn.Linear(d_model, head_size) # (Batch size, n_tokens, head_size)
    self.key = nn.Linear(d_model, head_size) # (Batch size, n_tokens, head_size)
    self.value = nn.Linear(d_model, head_size) # (Batch size, n_tokens, head_size)

  def forward(self, x, return_attn = False):
    # Obtaining Queries, Keys, and Values
    Q = self.query(x)
    K = self.key(x)
    V = self.value(x)

    # Dot Product of Queries and Keys
    attention = Q @ K.transpose(-2,-1)

    # Scaling
    attention = attention / (self.head_size ** 0.5) # (Batch size, n_tokens, n_tokens)

    attention = torch.softmax(attention, dim=-1) # (Batch size, n_tokens, n_tokens)

    out = attention @ V

    if return_attn:
        return out, attention
    return out # shape: (Batch size, n_tokens, head_size)

class MultiHeadAttention(nn.Module):
  def __init__(self, d_model, n_heads):
    super().__init__()
    self.head_size = d_model // n_heads

    self.W_o = nn.Linear(d_model, d_model)

    self.heads = nn.ModuleList([AttentionHead(d_model, self.head_size) for _ in range(n_heads)])

  def forward(self, x, return_attn = False):
    # Combine attention heads
    if return_attn:
        outs, weights = zip(*(h(x, True) for h in self.heads))   # lists of len = n_heads
        attn_weights = torch.stack(weights, dim=1)
        out = torch.cat(outs, dim=-1)                                # (B,T,d_model)
        out = self.W_o(out)
        return out, attn_weights

    else:
        out = torch.cat([head(x) for head in self.heads], dim=-1) # Shape: (Batch_size, n_tokens, head_size*num_heads = embedding_dim)
        out = self.W_o(out) # Shape: (Batch_size, n_tokens, head_size*num_heads = embedding_dim)
        return out

class TransformerEncoder(nn.Module):
  def __init__(self, d_model, n_heads, r_mlp=4):
    super().__init__()
    self.d_model = d_model
    self.n_heads = n_heads
    self.dropout = nn.Dropout(p=0.1)

    # Sub-Layer 1 Normalization
    self.ln1 = nn.LayerNorm(d_model)

    # Multi-Head Attention
    self.mha = MultiHeadAttention(d_model, n_heads)

    # Sub-Layer 2 Normalization
    self.ln2 = nn.LayerNorm(d_model)

    # Multilayer Perception
    self.mlp = nn.Sequential(
        nn.Linear(d_model, d_model*r_mlp),
        nn.GELU(),
        nn.Linear(d_model*r_mlp, d_model)
    )

  def forward(self, x, return_attn = False):

    if return_attn:
        attn_out, attn_w = self.mha(self.ln1(x), True)
        x = x + self.dropout(attn_out)
        x = x + self.dropout(self.mlp(self.ln2(x)))
        return x, attn_w
    else:
        # Residual Connection After Sub-Layer 1
        out = x + self.dropout(self.mha(self.ln1(x)))

        # Residual Connection After Sub-Layer 2
        out = out + self.dropout(self.mlp(self.ln2(out)))

        return out

class VisionTransformer(nn.Module):
  def __init__(self, d_model, n_classes, img_size, patch_size, n_channels, n_heads, n_layers):
    super().__init__()

    assert img_size[0] % patch_size[0] == 0 and img_size[1] % patch_size[1] == 0, "img_size dimensions must be divisible by patch_size dimensions"
    assert d_model % n_heads == 0, "d_model must be divisible by n_heads"

    self.d_model = d_model # Dimensionality of model
    self.n_classes = n_classes # Number of classes
    self.img_size = img_size # Image size
    self.patch_size = patch_size # Patch size
    self.n_channels = n_channels # Number of channels
    self.n_heads = n_heads # Number of attention heads
    self.dropout = nn.Dropout(p=0.1) # dropout

    self.n_patches = (self.img_size[0] * self.img_size[1]) // (self.patch_size[0] * self.patch_size[1])
    self.max_seq_length = self.n_patches + 1

    self.patch_embedding = PatchEmbedding(self.d_model, self.img_size, self.patch_size, self.n_channels)
    self.positional_encoding = PositionalEncoding( self.d_model, self.max_seq_length)
    self.transformer_encoder = nn.Sequential(*[TransformerEncoder( self.d_model, self.n_heads) for _ in range(n_layers)])

    # Classification MLP
    # self.classifier = nn.Sequential(
    #     nn.Linear(self.d_model, self.n_classes),
    #     nn.Softmax(dim=-1)
    # )
    self.classifier = nn.Linear(self.d_model, self.n_classes)

  def forward(self, images, return_attn=False):
    if return_attn:
        x = self.patch_embedding(images)
        x = self.positional_encoding(x)
        for layer in self.transformer_encoder[:-1]:
                x = layer(x)
        x, attn = self.transformer_encoder[-1](x, True)
        cls_repr = self.dropout(x[:, 0])
        logits   = self.classifier(cls_repr)
        return logits, attn

    else:
        x = self.patch_embedding(images)
        x = self.positional_encoding(x)
        x = self.transformer_encoder(x)
        x = self.dropout(x[:, 0])
        x = self.classifier(x)

        return x

import pytorch_lightning as pl
import torch.nn.functional as F
import torchmetrics
import torch

class ViTLightningModule(pl.LightningModule):
    def __init__(self, d_model=192, n_classes=10, img_size=(32,32), patch_size=(8,8),
                 n_channels=3, n_heads=4, n_layers=6, lr=3e-4):
        super().__init__()
        self.save_hyperparameters()

        self.model = VisionTransformer(
            d_model=d_model,
            n_classes=n_classes,
            img_size=img_size,
            patch_size=patch_size,
            n_channels=n_channels,
            n_heads=n_heads,
            n_layers=n_layers
        )

        self.loss_fn = torch.nn.CrossEntropyLoss()
        self.lr = lr

        # Metrics tracking:
        self.train_acc = torchmetrics.Accuracy(task="multiclass", num_classes=n_classes)
        self.val_acc   = torchmetrics.Accuracy(task="multiclass", num_classes=n_classes)
        self.test_acc  = torchmetrics.Accuracy(task="multiclass", num_classes=n_classes)

        self.test_f1  = torchmetrics.F1Score(task='multiclass', num_classes=n_classes, average=None)
        self.test_cm  = torchmetrics.ConfusionMatrix(task='multiclass', num_classes=n_classes)

    def forward(self, x,return_attn = False):
        return self.model(x, return_attn = return_attn)

    def common_step(self, batch):
        x, y = batch
        logits = self(x)
        loss = self.loss_fn(logits, y)
        return loss, logits, y

    def training_step(self, batch, batch_idx):
        loss, logits, y = self.common_step(batch)
        preds = torch.argmax(logits, dim=1)
        self.train_acc.update(preds, y)
        self.log("train_acc", self.train_acc, on_epoch=True, prog_bar=True)
        self.log("train_loss", loss, prog_bar=True)
        return loss

    def validation_step(self, batch, batch_idx):
        loss, logits, y = self.common_step(batch)
        preds = torch.argmax(logits, dim=1)
        self.val_acc.update(preds, y)
        self.log("val_acc", self.val_acc, on_epoch=True, prog_bar=True)
        self.log("validation loss", loss, prog_bar=True)
        return loss

    def test_step(self, batch, batch_idx):
        loss, logits, y = self.common_step(batch)
        preds = torch.argmax(logits, dim=1)
        self.test_acc.update(preds, y)
        self.test_f1.update(preds, y)
        self.test_cm.update(preds, y)
        self.log("test_acc", self.test_acc, on_epoch=True, prog_bar=True)
        self.log("test loss", loss, prog_bar=True)
        return loss

    def predict_step(self, batch, batch_idx):
        x, _ = batch
        logits = self(x)
        preds = torch.argmax(logits, dim=1)
        return preds

    def on_test_epoch_end(self):
        def plot_f1_scores(f1):
                    f1 = f1.detach().cpu().numpy()
                    class_names = [str(i) for i in range(10)]
                    fig, ax = plt.subplots(figsize=(8, 5))
                    bars = ax.bar(class_names, f1, alpha=0.7, edgecolor='black')

                    ax.set_xlabel("Class")
                    ax.set_ylabel("F1 score")
                    ax.set_title(f"Per class F1 (macro ≈ {f1.mean():.4f})")
                    ax.set_ylim(0, 1.1)
                    ax.grid(axis='y', linestyle='--', alpha=0.5)

                    for bar, score in zip(bars, f1):
                        ax.text(bar.get_x() + bar.get_width() / 2,
                                score + 0.02,
                                f"{score:.2f}",
                                ha='center', va='bottom', fontsize=10, fontweight='bold')

                    fig.tight_layout()
                    return fig

        def plot_conf_matrix(conf_mat):
            conf_mat = conf_mat.detach().cpu().numpy()
            row_sums = conf_mat.sum(axis=1, keepdims=True)
            conf_norm = np.divide(conf_mat, row_sums)
            n_classes = conf_norm.shape[0]
            class_names = [str(i) for i in range(n_classes)]
            df = pd.DataFrame(conf_norm, index=class_names, columns=class_names)

            fig, ax = plt.subplots(figsize=(8, 6))
            sns.heatmap(
                df,
                annot=True,
                fmt=".2f",
                cmap="Blues",
                vmin=0, vmax=1,
                cbar=True,
                ax=ax
            )
            ax.set_xlabel("Predicted label")
            ax.set_ylabel("True label")
            ax.set_title("Confusion matrix (row normalised)")
            fig.tight_layout()

            return fig

        f1_per_class =  self.test_f1.compute()
        fig1 = plot_f1_scores(f1_per_class)
        conf_mat = self.test_cm.compute()
        fig2 = plot_conf_matrix(conf_mat)


        self.logger.log_image("f1_scores",[fig1])
        self.logger.log_image("confusion_matrix",[fig2])

        self.test_f1.reset()
        self.test_cm.reset()

    def configure_optimizers(self):
        return torch.optim.AdamW(self.parameters(), lr=self.lr)


if __name__ == "__main__":
    pass
    # Test the workflow
    # d = 768
    # im_size = 32
    # patch_size = 8
    # n_channels = 3
    # n_heads = 16
    # head_size = d//n_heads
    #
    # patch_number = (im_size // patch_size)**2
    #
    # embedding = PatchEmbedding(d, im_size, patch_size, n_channels)
    # image = test_dataset.data[0]/ 255.0
    # tensor_image = torch.from_numpy(image)
    # tensor_image = tensor_image.permute(2, 0, 1)  # From (H, W, C) to (C, H, W)
    # tensor_image = tensor_image.unsqueeze(0).float()   # Shape becomes (1, C, H, W)
    # print("image shape: " + str(tensor_image.shape))  # Should be (1, 3, 224, 224)
    # embedding = embedding.forward(tensor_image)
    # print("embedding shape: " + str(embedding.shape))
    # positional_embedding = PositionalEncoding (d,patch_number+1)
    # embedding = positional_embedding.forward(embedding)
    # print("total embedding shape: " + str(embedding.shape))
    # multi_head_attention = MultiHeadAttention(d, n_heads)
    # embedding = multi_head_attention.forward(embedding)
    # print("total embedding shape after mha: " + str(embedding.shape))

# %% [markdown]
# b. Your model should achieve an accuracy of at least 0.70 on the training set, and at least 0.60 on both the validation and test sets.

# %% [markdown]
# first - oversample the data - to add more trainig samples

# %%
BATCH_SIZE = 256

class OversampledDataset(torch.utils.data.Dataset):
    def __init__(self, base_dataset, copies=3):
        self.base_dataset = base_dataset
        self.copies = copies

    def __len__(self):
        return len(self.base_dataset) * self.copies

    def __getitem__(self, idx):
        base_idx = idx % len(self.base_dataset)
        return self.base_dataset[base_idx]

cifar10_mean = (0.4914, 0.4822, 0.4465)
cifar10_std  = (0.2470, 0.2435, 0.2616)

train_augmented_transform = transforms.Compose([
    transforms.RandomApply([transforms.RandomCrop(32, padding=4)], p=0.33),
    transforms.RandomHorizontalFlip(p=0.33),
    transforms.RandomApply([transforms.ColorJitter(0.2, 0.2, 0.2, 0.1)], p=0.33),
    transforms.RandomApply([transforms.RandomRotation(15)],p=0.33),
    transforms.ToTensor(),
    transforms.Normalize(cifar10_mean,cifar10_std)
])

test_transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize(cifar10_mean,cifar10_std)
])

full_dataset = torchvision.datasets.CIFAR10(
    root='./data', train=True, download=True, transform=train_augmented_transform)

validation_dataset = torchvision.datasets.CIFAR10(
    root='./data', train=True, download=True, transform=test_transform)

test_dataset = torchvision.datasets.CIFAR10(root='./data', train=False, download=True, transform=test_transform)



targets = full_dataset.targets

train_idx, valid_idx= train_test_split(
    np.arange(len(targets)), test_size=0.4, random_state=24, shuffle=True, stratify=targets)

train_dataset = Subset(full_dataset, train_idx)
validation_dataset = Subset(validation_dataset, valid_idx)

# Apply transform to original CIFAR-10
oversampled_train_dataset = OversampledDataset(train_dataset, copies=3)
train_loader = DataLoader(oversampled_train_dataset, batch_size=BATCH_SIZE, shuffle=True)
validation_loader   = DataLoader(validation_dataset, batch_size=BATCH_SIZE, shuffle=False)

test_loader = DataLoader(dataset=test_dataset, batch_size=BATCH_SIZE, shuffle=False)

# %%
from pytorch_lightning.loggers import WandbLogger
import numpy as np
from pytorch_lightning.callbacks import EarlyStopping
from pytorch_lightning.callbacks import ModelCheckpoint


# 🪄 Init wandb logger
wandb_logger = WandbLogger(project="ViT-CIFAR10", log_model=True)

# ⚡ Instantiate model and trainer
model = ViTLightningModule(lr=3e-4,d_model=256,n_heads=8,n_layers=4)

# Define the checkpoint callback
early_stop = EarlyStopping(monitor="validation loss",mode="min", patience=10, verbose=True)
checkpoint_callback = ModelCheckpoint(save_top_k=1, monitor="validation loss", mode="min",verbose=True)

trainer = pl.Trainer(accelerator="gpu",devices=[0],min_epochs=5,max_epochs=50,callbacks=[early_stop,checkpoint_callback],logger=wandb_logger)

vit_train= False
# Out:
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs

# %%
vit_train = True
trainer.fit(model,train_loader,validation_loader)

# %% [markdown]
# c.

# %%
# 🔍 Evaluate
if vit_train:
    best_model = ViTLightningModule.load_from_checkpoint(checkpoint_callback.best_model_path)
else:
    best_model = ViTLightningModule.load_from_checkpoint("C:/Users/ndvam/PycharmProjects/deeplearning_hw3/vit_cifar10_best.ckpt")

trainer.validate(model=best_model,dataloaders=validation_loader)

trainer.test(model=best_model, dataloaders=test_loader)

#Show F1 score and confusion matrix you can do it in def on_test_epoch_end(self): and log it to wandb

if vit_train:
    # 💾 Save the model in thr last epoch if saved by metric
    trainer.save_checkpoint("vit_cifar10_best.ckpt")
    #Show F1 score and confusion matrix you can do it in def on_test_epoch_end(self): and log it to wandb
# Out:
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# C:\Users\ndvam\anaconda3\Lib\site-packages\pytorch_lightning\trainer\connectors\data_connector.py:425: The 'val_dataloader' does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` to `num_workers=15` in the `DataLoader` to improve performance.
# Validation: |          | 0/? [00:00<?, ?it/s]
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃      Validate metric      ┃       DataLoader 0        ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │          val_acc          │    0.6706500053405762     │
# │      validation loss      │    0.9865750074386597     │
# └───────────────────────────┴───────────────────────────┘
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# C:\Users\ndvam\anaconda3\Lib\site-packages\pytorch_lightning\trainer\connectors\data_connector.py:425: The 'test_dataloader' does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` to `num_workers=15` in the `DataLoader` to improve performance.
# Testing: |          | 0/? [00:00<?, ?it/s]
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃        Test metric        ┃       DataLoader 0        ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │         test loss         │     1.001083493232727     │
# │         test_acc          │    0.6608999967575073     │
# └───────────────────────────┴───────────────────────────┘

# %%
# Shows loss graph of best run
api = wandb.Api()
import wandb
import pandas as pd
import matplotlib.pyplot as plt
from scipy.ndimage import gaussian_filter1d

# Initialize W&B API
api = wandb.Api()

# Load your specific run
run = api.run("ndvamr-ben-gurion-university-of-the-negev/ViT-CIFAR10/qahrxi7k")

train_dataset_size = 30000
steps_per_epoch = train_dataset_size // BATCH_SIZE



df_tl = run.history(keys=["train_loss","epoch"])
df_tl = pd.DataFrame(df_tl)



df_vl = run.history(keys=["validation loss","epoch"])
df_vl = pd.DataFrame(df_vl)


# Apply Gaussian smoothing (sigma can be tuned)
train_loss_smoothed = gaussian_filter1d(df_tl["train_loss"].fillna(method="ffill"), sigma=3)
val_loss_smoothed = gaussian_filter1d(df_vl["validation loss"].fillna(method="ffill"), sigma=1)

# Plot both
plt.figure(figsize=(10, 5))
plt.plot(df_tl["epoch"], train_loss_smoothed, label="Train Loss (smoothed)")
plt.plot(df_vl["epoch"], val_loss_smoothed, label="Validation Loss (smoothed)")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.title("Training & Validation Loss")
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# C:\Users\ndvam\AppData\Local\Temp\ipykernel_235108\1737357758.py:29: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   train_loss_smoothed = gaussian_filter1d(df_tl["train_loss"].fillna(method="ffill"), sigma=3)
# C:\Users\ndvam\AppData\Local\Temp\ipykernel_235108\1737357758.py:30: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   val_loss_smoothed = gaussian_filter1d(df_vl["validation loss"].fillna(method="ffill"), sigma=1)

# %% [markdown]
# ### 2.2 Visualizing Attention Maps

# %%
import cv2
def visualize_attention(model, image_tensor):
    model.eval()
    with torch.no_grad():
        logits, attn = model(image_tensor, return_attn=True)
        attn = attn.squeeze(0)
        attn = attn.mean(0)
        cls_to_patch = attn[0, 1:]
        num_patches  = cls_to_patch.numel()
        grid_size    = int(np.sqrt(num_patches))         # assumes square grid
        attn_grid    = cls_to_patch.reshape(grid_size, grid_size)

        heat = F.interpolate(
            attn_grid.unsqueeze(0).unsqueeze(0),         # (1,1,G,G)
            size=image_tensor.shape[-2:],                # (H, W)
            mode="bilinear",
            align_corners=False
        )[0, 0].cpu().numpy()

        # Convert image tensor to numpy and transpose to (H, W, 3)
        img_np = image_tensor.squeeze(0).cpu().permute(1, 2, 0).numpy()
        img_np = (img_np - img_np.min()) / (img_np.max() - img_np.min())  # normalize for display

        fig, axs = plt.subplots(1, 2, figsize=(10, 5))

        # Original image
        axs[0].imshow(img_np)
        axs[0].set_title("Original Image")
        axs[0].axis("off")

        # Attention heatmap
        axs[1].imshow(img_np)
        axs[1].imshow(heat, cmap='jet', alpha=0.5)  # Overlay
        axs[1].set_title("CLS Attention Heatmap")
        axs[1].axis("off")

        plt.tight_layout()
        plt.show()

from pytorch_grad_cam.utils.model_targets import ClassifierOutputTarget
import random
import numpy as np

cifar10_mean = (0.4914, 0.4822, 0.4465)
cifar10_std  = (0.2470, 0.2435, 0.2616)

rgb_img = test_dataset.data[344]/255.0

best_model = ViTLightningModule.load_from_checkpoint("C:/Users/ndvam/PycharmProjects/deeplearning_hw3/vit_cifar10_best.ckpt")
input_tensor = preprocess_image(rgb_img,mean=cifar10_mean,std=cifar10_std).float().to(best_model.device)

visualize_attention(best_model, input_tensor)

# %%
import torch
import torch.nn.functional as F
import numpy as np
import matplotlib.pyplot as plt
import random

# CIFAR-10 normalization
cifar10_mean = (0.4914, 0.4822, 0.4465)
cifar10_std  = (0.2470, 0.2435, 0.2616)

# Utility: map class index to name
def get_class_name_from_idx(dictionary, idx):
    for key, value in dictionary.items():
        if value == idx:
            return key

# Utility: preprocess CIFAR-10 image
def preprocess_image(img_np, mean, std):
    img_tensor = torch.tensor(img_np).permute(2, 0, 1).unsqueeze(0)  # (1,3,H,W)
    for t, m, s in zip(img_tensor[0], mean, std):
        t.sub_(m).div_(s)
    return img_tensor

# === Main visualization function for ViT ===
def show_vit_attention_examples(model, dataset,equal_tags,random_seed):
    model.eval()
    sample_targets = []
    sample_indices = []

    random.seed(random_seed)
    for k, target in enumerate(dataset.targets):
        if random.random() < 0.05:
            rgb_img = dataset.data[k] / 255.0
            input_tensor = preprocess_image(rgb_img, cifar10_mean, cifar10_std).float()

            with torch.no_grad():
                logits = model(input_tensor, return_attn=False)
                pred_idx = int(logits.argmax())
            if equal_tags:
                if pred_idx == target and target not in sample_targets:
                    sample_indices.append(k)
                    sample_targets.append(target)
            else:
                if pred_idx != target and target not in sample_targets:
                    sample_indices.append(k)
                    sample_targets.append(target)

            if len(sample_targets) == 10:
                break

    sorted_indices_by_target = np.argsort(sample_targets)
    fig, axs = plt.subplots(nrows=2, ncols=5, figsize=(20, 8))

    index = 0
    for k in sorted_indices_by_target[[1, 5, 0, 2, 3]]:
        idx = sample_indices[k]
        true_class = sample_targets[k]
        rgb_img = dataset.data[idx] / 255.0

        axs[0, index].imshow(rgb_img)
        axs[0, index].axis("off")
        axs[0, index].set_title(f"Category: {get_class_name_from_idx(dataset.class_to_idx, true_class)}")

        input_tensor = preprocess_image(rgb_img, cifar10_mean, cifar10_std).float()

        with torch.no_grad():
            logits, attn = model(input_tensor, return_attn=True)
            pred_class = int(logits.argmax())

            # Process attention
            attn = attn.squeeze(0)          # (heads, 17, 17)
            attn = attn.mean(0)             # (17, 17)
            cls_to_patch = attn[0, 1:]      # (16,)
            grid_size = int(np.sqrt(cls_to_patch.numel()))
            attn_grid = cls_to_patch.reshape(grid_size, grid_size)
            heat = F.interpolate(attn_grid.unsqueeze(0).unsqueeze(0),
                                 size=input_tensor.shape[-2:],
                                 mode="bilinear",
                                 align_corners=False)[0, 0].cpu().numpy()

        # Overlay attention on image
        img_np = input_tensor.squeeze(0).cpu().permute(1, 2, 0).numpy()
        img_np = (img_np - img_np.min()) / (img_np.max() - img_np.min())

        axs[1, index].imshow(img_np)
        axs[1, index].imshow(heat, cmap='jet', alpha=0.5)
        axs[1, index].axis("off")
        axs[1, index].set_title(f"CLS attention maps, Pred: {get_class_name_from_idx(dataset.class_to_idx, pred_class)}")

        index += 1
        if index == 5:
            break

    fig.tight_layout()
    plt.show()

# %%
show_vit_attention_examples(best_model, test_dataset,equal_tags = True,random_seed=25)

# %%
show_vit_attention_examples(best_model, test_dataset,equal_tags = False,random_seed=58)

# %% [markdown]
# same example for both methods

# %%
from pytorch_grad_cam import GradCAM
from pytorch_grad_cam.utils.image import show_cam_on_image, preprocess_image
from pytorch_grad_cam.utils.model_targets import ClassifierOutputTarget
import random
import numpy as np

def visualize_cnn_grad_cam(image_index):
    # load the model again
    model = SimpleCNN.load_from_checkpoint("cnn_cifar10_best.ckpt")
    model.eval()

    # Define the target layer for Grad-CAM (adjust if needed)
    target_layer = model.features[-1][0]
    cam = GradCAM(model=model, target_layers=[target_layer])

    rgb_img = test_dataset.data[image_index]/255.0
    category = test_dataset.targets[image_index]

    fig, axs = plt.subplots(nrows=2, ncols=1, figsize=(20, 10))
    axs[0]. grid(False)
    axs[0].set_title(f"Original Image")
    axs[0].axis("off")
    axs[0].imshow(rgb_img)

    input_tensor = preprocess_image(rgb_img,mean=cifar10_mean,std=cifar10_std).float()

    # Show what model predicted
    with torch.no_grad():
        logits = model(input_tensor)
        pred_idx  = int(logits.argmax())

    grayscale_cam = cam(input_tensor=input_tensor, targets=[ClassifierOutputTarget(category)])
    grayscale_cam = grayscale_cam[0, :]
    visualization = show_cam_on_image(rgb_img, grayscale_cam, use_rgb=True)

    axs[1]. grid(False)
    axs[1].set_title(f"GradCam - True - {get_class_name_from_idx(dataset.class_to_idx,category)}, "
                           f"Prediction - {get_class_name_from_idx(dataset.class_to_idx,pred_idx)}")
    axs[1].axis("off")
    axs[1].imshow(visualization)
    plt.tight_layout()
    plt.show()

def visualize_attention(image_index):

    model = ViTLightningModule.load_from_checkpoint("C:/Users/ndvam/PycharmProjects/deeplearning_hw3/vit_cifar10_best.ckpt")
    model.eval()

    cifar10_mean = (0.4914, 0.4822, 0.4465)
    cifar10_std  = (0.2470, 0.2435, 0.2616)

    rgb_img = test_dataset.data[image_index]/255.0
    image_tensor = preprocess_image(rgb_img,mean=cifar10_mean,std=cifar10_std).float().to(best_model.device)

    with torch.no_grad():
        logits, attn = model(image_tensor, return_attn=True)
        category = test_dataset.targets[image_index]
        pred_idx = np.argmax(logits.squeeze(0).cpu().numpy())
        attn = attn.squeeze(0)
        attn = attn.mean(0)
        cls_to_patch = attn[0, 1:]
        num_patches  = cls_to_patch.numel()
        grid_size    = int(np.sqrt(num_patches))         # assumes square grid
        attn_grid    = cls_to_patch.reshape(grid_size, grid_size)

        heat = F.interpolate(
            attn_grid.unsqueeze(0).unsqueeze(0),         # (1,1,G,G)
            size=image_tensor.shape[-2:],                # (H, W)
            mode="bilinear",
            align_corners=False
        )[0, 0].cpu().numpy()

        # Convert image tensor to numpy and transpose to (H, W, 3)
        img_np = image_tensor.squeeze(0).cpu().permute(1, 2, 0).numpy()
        img_np = (img_np - img_np.min()) / (img_np.max() - img_np.min())  # normalize for display

        fig, axs = plt.subplots(nrows=2, ncols=1, figsize=(20, 10))

        # Original image
        axs[0].imshow(img_np)
        axs[0].set_title("Original Image")
        axs[0].axis("off")

        # Attention heatmap
        axs[1].imshow(img_np)
        axs[1].imshow(heat, cmap='jet', alpha=0.5)  # Overlay
        axs[1].set_title((f"Attention map - True - {get_class_name_from_idx(dataset.class_to_idx,category)}, "
                           f"Prediction - {get_class_name_from_idx(dataset.class_to_idx,pred_idx)}"))
        axs[1].axis("off")

        plt.tight_layout()
        plt.show()


random.seed()
zero_indices = [i for i, t in enumerate(test_dataset.targets) if t == 0]
idx = random.choice(zero_indices)
print(idx)
visualize_attention(idx)
visualize_cnn_grad_cam(idx)
# Out:
# 6347

# %% [markdown]
# calculate number of parameters for each model:

# %%
from torchsummary import summary
vit =  ViTLightningModule.load_from_checkpoint("C:/Users/ndvam/PycharmProjects/deeplearning_hw3/vit_cifar10_best.ckpt")
summary(vit,(3,32,32))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1            [-1, 256, 4, 4]          49,408
#     PatchEmbedding-2              [-1, 16, 256]               0
# PositionalEncoding-3              [-1, 17, 256]               0
#          LayerNorm-4              [-1, 17, 256]             512
#             Linear-5               [-1, 17, 32]           8,224
#             Linear-6               [-1, 17, 32]           8,224
#             Linear-7               [-1, 17, 32]           8,224
#      AttentionHead-8               [-1, 17, 32]               0
#             Linear-9               [-1, 17, 32]           8,224
#            Linear-10               [-1, 17, 32]           8,224
#            Linear-11               [-1, 17, 32]           8,224
#     AttentionHead-12               [-1, 17, 32]               0
#            Linear-13               [-1, 17, 32]           8,224
#            Linear-14               [-1, 17, 32]           8,224
#            Linear-15               [-1, 17, 32]           8,224
#     AttentionHead-16               [-1, 17, 32]               0
#            Linear-17               [-1, 17, 32]           8,224
#            Linear-18               [-1, 17, 32]           8,224
#            Linear-19               [-1, 17, 32]           8,224
#     AttentionHead-20               [-1, 17, 32]               0
#            Linear-21               [-1, 17, 32]           8,224
#            Linear-22               [-1, 17, 32]           8,224
#            Linear-23               [-1, 17, 32]           8,224
#     AttentionHead-24               [-1, 17, 32]               0
#            Linear-25               [-1, 17, 32]           8,224
#            Linear-26               [-1, 17, 32]           8,224
#            Linear-27               [-1, 17, 32]           8,224
#     AttentionHead-28               [-1, 17, 32]               0
#            Linear-29               [-1, 17, 32]           8,224
#            Linear-30               [-1, 17, 32]           8,224
#            Linear-31               [-1, 17, 32]           8,224
#     AttentionHead-32               [-1, 17, 32]               0
#            Linear-33               [-1, 17, 32]           8,224
#            Linear-34               [-1, 17, 32]           8,224
#            Linear-35               [-1, 17, 32]           8,224
#     AttentionHead-36               [-1, 17, 32]               0
#            Linear-37              [-1, 17, 256]          65,792
# MultiHeadAttention-38              [-1, 17, 256]               0
#           Dropout-39              [-1, 17, 256]               0
#         LayerNorm-40              [-1, 17, 256]             512
#            Linear-41             [-1, 17, 1024]         263,168
#              GELU-42             [-1, 17, 1024]               0
#            Linear-43              [-1, 17, 256]         262,400
#           Dropout-44              [-1, 17, 256]               0
# TransformerEncoder-45              [-1, 17, 256]               0
#         LayerNorm-46              [-1, 17, 256]             512
#            Linear-47               [-1, 17, 32]           8,224
#            Linear-48               [-1, 17, 32]           8,224
#            Linear-49               [-1, 17, 32]           8,224
#     AttentionHead-50               [-1, 17, 32]               0
#            Linear-51               [-1, 17, 32]           8,224
#            Linear-52               [-1, 17, 32]           8,224
#            Linear-53               [-1, 17, 32]           8,224
#     AttentionHead-54               [-1, 17, 32]               0
#            Linear-55               [-1, 17, 32]           8,224
#            Linear-56               [-1, 17, 32]           8,224
#            Linear-57               [-1, 17, 32]           8,224
#     AttentionHead-58               [-1, 17, 32]               0
#            Linear-59               [-1, 17, 32]           8,224
#            Linear-60               [-1, 17, 32]           8,224
#            Linear-61               [-1, 17, 32]           8,224
#     AttentionHead-62               [-1, 17, 32]               0
#            Linear-63               [-1, 17, 32]           8,224
#            Linear-64               [-1, 17, 32]           8,224
#            Linear-65               [-1, 17, 32]           8,224
#     AttentionHead-66               [-1, 17, 32]               0
#            Linear-67               [-1, 17, 32]           8,224
#            Linear-68               [-1, 17, 32]           8,224
#            Linear-69               [-1, 17, 32]           8,224
#     AttentionHead-70               [-1, 17, 32]               0
#            Linear-71               [-1, 17, 32]           8,224
#            Linear-72               [-1, 17, 32]           8,224
#            Linear-73               [-1, 17, 32]           8,224
#     AttentionHead-74               [-1, 17, 32]               0
#            Linear-75               [-1, 17, 32]           8,224
#            Linear-76               [-1, 17, 32]           8,224
#            Linear-77               [-1, 17, 32]           8,224
#     AttentionHead-78               [-1, 17, 32]               0
#            Linear-79              [-1, 17, 256]          65,792
# MultiHeadAttention-80              [-1, 17, 256]               0
#           Dropout-81              [-1, 17, 256]               0
#         LayerNorm-82              [-1, 17, 256]             512
#            Linear-83             [-1, 17, 1024]         263,168
#              GELU-84             [-1, 17, 1024]               0
#            Linear-85              [-1, 17, 256]         262,400
#           Dropout-86              [-1, 17, 256]               0
# TransformerEncoder-87              [-1, 17, 256]               0
#         LayerNorm-88              [-1, 17, 256]             512
#            Linear-89               [-1, 17, 32]           8,224
#            Linear-90               [-1, 17, 32]           8,224
#            Linear-91               [-1, 17, 32]           8,224
#     AttentionHead-92               [-1, 17, 32]               0
#            Linear-93               [-1, 17, 32]           8,224
#            Linear-94               [-1, 17, 32]           8,224
#            Linear-95               [-1, 17, 32]           8,224
#     AttentionHead-96               [-1, 17, 32]               0
#            Linear-97               [-1, 17, 32]           8,224
#            Linear-98               [-1, 17, 32]           8,224
#            Linear-99               [-1, 17, 32]           8,224
#    AttentionHead-100               [-1, 17, 32]               0
#           Linear-101               [-1, 17, 32]           8,224
#           Linear-102               [-1, 17, 32]           8,224
#           Linear-103               [-1, 17, 32]           8,224
#    AttentionHead-104               [-1, 17, 32]               0
#           Linear-105               [-1, 17, 32]           8,224
#           Linear-106               [-1, 17, 32]           8,224
#           Linear-107               [-1, 17, 32]           8,224
#    AttentionHead-108               [-1, 17, 32]               0
#           Linear-109               [-1, 17, 32]           8,224
#           Linear-110               [-1, 17, 32]           8,224
#           Linear-111               [-1, 17, 32]           8,224
#    AttentionHead-112               [-1, 17, 32]               0
#           Linear-113               [-1, 17, 32]           8,224
#           Linear-114               [-1, 17, 32]           8,224
#           Linear-115               [-1, 17, 32]           8,224
#    AttentionHead-116               [-1, 17, 32]               0
#           Linear-117               [-1, 17, 32]           8,224
#           Linear-118               [-1, 17, 32]           8,224
#           Linear-119               [-1, 17, 32]           8,224
#    AttentionHead-120               [-1, 17, 32]               0
#           Linear-121              [-1, 17, 256]          65,792
# MultiHeadAttention-122              [-1, 17, 256]               0
#          Dropout-123              [-1, 17, 256]               0
#        LayerNorm-124              [-1, 17, 256]             512
#           Linear-125             [-1, 17, 1024]         263,168
#             GELU-126             [-1, 17, 1024]               0
#           Linear-127              [-1, 17, 256]         262,400
#          Dropout-128              [-1, 17, 256]               0
# TransformerEncoder-129              [-1, 17, 256]               0
#        LayerNorm-130              [-1, 17, 256]             512
#           Linear-131               [-1, 17, 32]           8,224
#           Linear-132               [-1, 17, 32]           8,224
#           Linear-133               [-1, 17, 32]           8,224
#    AttentionHead-134               [-1, 17, 32]               0
#           Linear-135               [-1, 17, 32]           8,224
#           Linear-136               [-1, 17, 32]           8,224
#           Linear-137               [-1, 17, 32]           8,224
#    AttentionHead-138               [-1, 17, 32]               0
#           Linear-139               [-1, 17, 32]           8,224
#           Linear-140               [-1, 17, 32]           8,224
#           Linear-141               [-1, 17, 32]           8,224
#    AttentionHead-142               [-1, 17, 32]               0
#           Linear-143               [-1, 17, 32]           8,224
#           Linear-144               [-1, 17, 32]           8,224
#           Linear-145               [-1, 17, 32]           8,224
#    AttentionHead-146               [-1, 17, 32]               0
#           Linear-147               [-1, 17, 32]           8,224
#           Linear-148               [-1, 17, 32]           8,224
#           Linear-149               [-1, 17, 32]           8,224
#    AttentionHead-150               [-1, 17, 32]               0
#           Linear-151               [-1, 17, 32]           8,224
#           Linear-152               [-1, 17, 32]           8,224
#           Linear-153               [-1, 17, 32]           8,224
#    AttentionHead-154               [-1, 17, 32]               0
#           Linear-155               [-1, 17, 32]           8,224
#           Linear-156               [-1, 17, 32]           8,224
#           Linear-157               [-1, 17, 32]           8,224
#    AttentionHead-158               [-1, 17, 32]               0
#           Linear-159               [-1, 17, 32]           8,224
#           Linear-160               [-1, 17, 32]           8,224
#           Linear-161               [-1, 17, 32]           8,224
#    AttentionHead-162               [-1, 17, 32]               0
#           Linear-163              [-1, 17, 256]          65,792
# MultiHeadAttention-164              [-1, 17, 256]               0
#          Dropout-165              [-1, 17, 256]               0
#        LayerNorm-166              [-1, 17, 256]             512
#           Linear-167             [-1, 17, 1024]         263,168
#             GELU-168             [-1, 17, 1024]               0
#           Linear-169              [-1, 17, 256]         262,400
#          Dropout-170              [-1, 17, 256]               0
# TransformerEncoder-171              [-1, 17, 256]               0
#          Dropout-172                  [-1, 256]               0
#           Linear-173                   [-1, 10]           2,570
# VisionTransformer-174                   [-1, 10]               0
# ================================================================
# Total params: 3,211,018
# Trainable params: 3,211,018
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.01
# Forward/backward pass size (MB): 2.75
# Params size (MB): 12.25
# Estimated Total Size (MB): 15.01
# ----------------------------------------------------------------

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
cnn = SimpleCNN.load_from_checkpoint("C:/Users/ndvam/PycharmProjects/deeplearning_hw3/cnn_cifar10_best.ckpt")
cnn.eval().cpu()
cnn.eval().to(device)
summary(cnn,(3,32,32), device=str(device))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1           [-1, 64, 32, 32]           1,728
#        BatchNorm2d-2           [-1, 64, 32, 32]             128
#               ReLU-3           [-1, 64, 32, 32]               0
#             Conv2d-4           [-1, 64, 32, 32]          36,864
#        BatchNorm2d-5           [-1, 64, 32, 32]             128
#               ReLU-6           [-1, 64, 32, 32]               0
#          MaxPool2d-7           [-1, 64, 16, 16]               0
#             Conv2d-8          [-1, 128, 16, 16]          73,728
#        BatchNorm2d-9          [-1, 128, 16, 16]             256
#              ReLU-10          [-1, 128, 16, 16]               0
#            Conv2d-11          [-1, 128, 16, 16]         147,456
#       BatchNorm2d-12          [-1, 128, 16, 16]             256
#              ReLU-13          [-1, 128, 16, 16]               0
#         MaxPool2d-14            [-1, 128, 8, 8]               0
#            Conv2d-15            [-1, 256, 8, 8]         294,912
#       BatchNorm2d-16            [-1, 256, 8, 8]             512
#              ReLU-17            [-1, 256, 8, 8]               0
#            Conv2d-18            [-1, 256, 8, 8]         589,824
#       BatchNorm2d-19            [-1, 256, 8, 8]             512
#              ReLU-20            [-1, 256, 8, 8]               0
# AdaptiveAvgPool2d-21            [-1, 256, 1, 1]               0
#           Dropout-22                  [-1, 256]               0
#            Linear-23                   [-1, 10]           2,570
# ================================================================
# Total params: 1,148,874
# Trainable params: 1,148,874
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.01
# Forward/backward pass size (MB): 5.44
# Params size (MB): 4.38
# Estimated Total Size (MB): 9.84
# ----------------------------------------------------------------
